# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
import importlib
import tm

importlib.reload(tm)
# Out:
# <module 'tm' from 'C:\\Users\\rui_j\\Desktop\\tm\\tm\\__init__.py'>
